# %% [markdown]
# <a href="https://colab.research.google.com/github/DyonatanRosa/Ciencia_de_Dados/blob/main/Aula_1_e_2_Ciencia_de_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello Word")
# Out:
# Hello Word

# %%
a = 5
b = 3.14
c = "programação"


print(a, type(a))
print(b, type(b))
print(b, type(c))
# Out:
# 5 <class 'int'>
# 3.14 <class 'float'>
# 3.14 <class 'str'>

# %%
valor = int (input("Informe um valor qualquer: "))

soma =  valor + 10

print(soma)
# Out:
# Informe um valor qualquer: 10
# 20

# %% [markdown]
# Quando solicitar pro usuário algo diferente de String, precisa fazer a conversão para a variável utilizada, no caso aqui foi utilizado o int

# %%
opcao_verdadeira = True
opcao_falsa = False

# Mostrando os valores na tela
print("O valor da primeira variável é:", opcao_verdadeira)
print("O valor da segunda variável é:", opcao_falsa)
# Out:
# O valor da primeira variável é: True
# O valor da segunda variável é: False

# %%
L = [2, 4, 5.98, "Programação", (4,7)]

print(L)

print (L[1])
print (L[4])
rint (L[4][1])
# Out:
# [2, 4, 5.98, 'Programação', (4, 7)]
# 4
# (4, 7)
# 7

# %%
T = [10, "Programa", 200]

print(T[1])


A, B, C = T

print(A)
print(B)
print(C)
# Out:
# Programa
# 10
# Programa
# 200

# %%
import math
print(math.factorial(6))

from math import factorial
print(factorial(6))
# Out:
# 720
# 720

# %%
km = float (input("Informe o valor em km/h: "))

m = km / 3.6

print(m)
# Out:
# Informe o valor em km/h: 50
# 13.88888888888889

# %%
from math import sqrt

p1x = int (input("Informe a coordenada x do ponto 1: "))
p1y = int (input("Informe a coordenada y do ponto 1: "))

p2x = int (input("Informe a coordenada x do ponto 2: "))
p2y = int (input("Informe a coordenada y do ponto 2: "))

coord = sqrt ((p2x - p1x) ** 2 + (p2y - p1y) ** 2)

print(coord)
# Out:
# Informe a coordenada x do ponto 1: 12
# Informe a coordenada y do ponto 1: 37
# Informe a coordenada x do ponto 2: 21
# Informe a coordenada y do ponto 2: 26
# 14.212670403551895

# %%
nome = (input("Digite seu nome: "))
imoveis = int (input("Digite a quantidade de imóveis vendidos: "))
total = float (input("Digite o valor total em vendas: "))

sal = (2500.00 + (500.00 * imoveis) + total * 0.05)

print(sal)
# Out:
# Digote seu nome: Dyonatan
# Digite a quantidade de imóveis vendidos: 5
# Digite o valor total em vendas: 250000
# 17500.0
